# %%
import pandas as pd
import numpy as np
import seaborn as sb
from matplotlib import pyplot as plt

# %%
mydata=pd.read_excel(r"D:\Machine_Learning\Data_sets\DataSets-master\Cricket_Data.xlsx")

# %%
mydata
# Out:
#     Mat  Inns  Runs    Ave      SR CATEGORY
# 0    58   104  4154  41.95   51.49     TEST
# 1   147   143  5238  39.68   85.25      ODI
# 2    71   122  6147  53.92   58.22     TEST
# 3   211   203  9779  58.20   92.12      ODI
# 4    62    58  2102  48.88  136.22      T20
# ..  ...   ...   ...    ...     ...      ...
# 70   77    71  1825  37.24  124.31      T20
# 71   62   105  4809  49.57   46.90     TEST
# 72   25    43  1479  39.97   55.14     TEST
# 73  183   177  6748  44.98   87.18      ODI
# 74   84    77  2086  32.59  137.05      T20
#
# [75 rows x 6 columns]

# %%
mydata.head()
# Out:
#    Mat  Inns  Runs    Ave      SR CATEGORY
# 0   58   104  4154  41.95   51.49     TEST
# 1  147   143  5238  39.68   85.25      ODI
# 2   71   122  6147  53.92   58.22     TEST
# 3  211   203  9779  58.20   92.12      ODI
# 4   62    58  2102  48.88  136.22      T20

# %%
X_feature=mydata.iloc[:,0:5]

# %%
X_feature.head()
# Out:
#    Mat  Inns  Runs    Ave      SR
# 0   58   104  4154  41.95   51.49
# 1  147   143  5238  39.68   85.25
# 2   71   122  6147  53.92   58.22
# 3  211   203  9779  58.20   92.12
# 4   62    58  2102  48.88  136.22

# %%
def corrWith(f1,f2,yourdata,hueval="No"):
    if hueval=="No":
        sb.lmplot(f1,f2,data=yourdata,fit_reg=True,scatter_kws={"s":200})
        plt.title("Corr plot betwwen {} and {}".format(f1,f2))
        plt.xlabel(f1)
        plt.ylabel(f2)
        plt.show()
    else:
        sb.lmplot(f1,f2,data=yourdata,fit_reg=False,scatter_kws={"s":200},hue=hueval)
        plt.title("Corr plot betwwen {} and {}".format(f1,f2))
        plt.xlabel(f1)
        plt.ylabel(f2)
        plt.show()

# %%
# Corr with 
corrWith("Mat","Inns",X_feature)
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrWith("Mat","Runs",X_feature)
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrWith("Inns","Runs",X_feature)
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrWith("Inns","SR",X_feature)
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrWith("Ave","Inns",X_feature)
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
XA_feature=X_feature.values

# %%
print("Type of XA_feature {} and type of X_feature {}".format(type(XA_feature),type(X_feature)))
# Out:
# Type of XA_feature <class 'numpy.ndarray'> and type of X_feature <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.cluster import KMeans

# %%
k=3

# %%
k_Cluster=KMeans(n_clusters=k).fit(XA_feature)

# %%
kValue=k_Cluster.cluster_centers_
print("value of means")
# Out:
# value of means

# %%
kValue[0].tolist()
# Out:
# [55.44444444444444,
#  56.911111111111076,
#  1668.5333333333342,
#  31.67955555555556,
#  103.19666666666666,
#  -1.1102230246251565e-16]

# %%
ColName=X_feature.columns.tolist()
pd.DataFrame([kValue[0].tolist(),kValue[1],kValue[2].tolist()],index=["c1","c2","c3"],columns=ColName)
# Out:
#            Mat        Inns          Runs        Ave          SR       Cluster
# c1   55.444444   56.911111   1668.533333  31.679556  103.196667 -1.110223e-16
# c2  136.111111  157.000000   6481.481481  48.514074   73.467778  1.000000e+00
# c3  274.666667  357.333333  15606.333333  47.986667   63.800000  2.000000e+00

# %%
X_feature["Cluster"]=k_Cluster.labels_

# %%
X_feature
# Out:
#     Mat  Inns  Runs    Ave      SR  Cluster
# 0    58   104  4154  41.95   51.49        1
# 1   147   143  5238  39.68   85.25        1
# 2    71   122  6147  53.92   58.22        1
# 3   211   203  9779  58.20   92.12        1
# 4    62    58  2102  48.88  136.22        0
# ..  ...   ...   ...    ...     ...      ...
# 70   77    71  1825  37.24  124.31        0
# 71   62   105  4809  49.57   46.90        1
# 72   25    43  1479  39.97   55.14        0
# 73  183   177  6748  44.98   87.18        1
# 74   84    77  2086  32.59  137.05        0
#
# [75 rows x 6 columns]

# %%
X_feature.head(1)
# Out:
#    Mat  Inns  Runs    Ave     SR  Cluster
# 0   58   104  4154  41.95  51.49        1

# %%
corrWith("Mat","Inns",X_feature,hueval="Cluster")
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrWith("Inns","SR",X_feature,hueval="Cluster")
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrWith("Runs","Inns",X_feature)
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrWith("Mat","Ave",X_feature,hueval="Cluster")
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
k=range(1,10)

# %%
wssErrorList=[]
for i in k:
    KmeanCluster=KMeans(n_clusters=i)
    KmeanCluster=KmeanCluster.fit(XA_feature)
    wssError=KmeanCluster.inertia_
    wssErrorList.append(wssError)
# Out:
# C:\Users\oksin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(k,wssErrorList,'bx-')
plt.plot("K Value")
plt.ylabel("Sum of with in cluster error")
plt.title("Elow method for finding Number Cluster ")
plt.show()
